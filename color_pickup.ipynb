# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("sake.png")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
#HSV
img_hsv = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img_rgb),plt.show()
plt.imshow(gray, cmap ='gray'),plt.show()
plt.imshow(img_hsv),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x118d16438>, None)

# %%
max = 0
min = 255
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if img_rgb[i,j,0] > 80 and img_rgb[i,j,1] < 70 and img_rgb[i,j,2] < 70:
#             rgb_to_gray(img_rgb,i,j)
            img_rgb[i,j] = [255,255,255]
#             pass

plt.imshow(img_rgb),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x118c71da0>, None)

# %%
red = np.uint8([[[255,0,0 ]]])
hsv_red = cv2.cvtColor(red,cv2.COLOR_BGR2HSV)
print (hsv_red)
# Out:
# [[[120 255 255]]]

# %%
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        if 120 < img_hsv[i,j,0] < 130:
#             img_rgb[i,j] = [255,255,255]
            pass
        else:
            img_hsv[i,j] = [255,255,255]

plt.imshow(img_hsv),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x118086978>, None)
